# %% [markdown]
# # Extract

# %%
import pandas as pd
import os

# %%
print("Current Working Directory :=>", os.getcwd())
# Out:
# Current Working Directory :=> D:\Users\coit25\Documents\Workspace\Python\Projects\IT_Helpdesk_Ticket_Analysis\etl

# %%
file_path = os.path.join('..','data', 'raw_tickets.csv')

# Check if file exists
if not os.path.exists(file_path):
    print("File not found. Please add raw_tickets.csv to the /data folder.")
else:
    print("File found:", file_path)
# Out:
# File found: ..\data\raw_tickets.csv

# %%
df_raw = pd.read_csv(file_path)
df_raw
# Out:
# C:\Users\coit25\AppData\Local\Temp\ipykernel_29576\171513078.py:1: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv(file_path)
#        ticketid  Ticket      CreationDate       LastUpdated  \
# 0         26250  #26250    6/23/2023 3:19   6/23/2023 10:51
# 1         26249  #26249    6/23/2023 3:19   6/23/2023 10:51
# 2         26248  #26248    6/23/2023 3:19   6/23/2023 10:51
# 3         26247  #26247    6/23/2023 3:19   6/23/2023 10:51
# 4         26246  #26246    6/23/2023 3:19   6/23/2023 10:51
# ...         ...     ...               ...               ...
# 17701     37462  #37462  10/23/2023 10:52   11/2/2023 11:40
# 17702     37414  #37414   10/20/2023 9:02   1/22/2024 12:10
# 17703     37363  #37363  10/18/2023 14:08  10/25/2023 14:49
# 17704     37297  #37297  10/16/2023 11:40   12/6/2023 16:35
# 17705     37295  #37295  10/16/2023 11:25   12/6/2023 16:35
#
#                       Type           State Priority   Source  \
# 0      Application Support  Resolved by IT   Medium    Email
# 1      Application Support  Resolved by IT   Medium    Email
# 2      Application Support  Resolved by IT   Medium    Email
# 3      Application Support  Resolved by IT   Medium    Email
# 4      Application Support  Resolved by IT   Medium    Email
# ...                    ...             ...      ...      ...
# 17701  Application Support          Closed   Medium  Website
# 17702  Application Support          Closed   Medium  Website
# 17703  Application Support          Closed   Medium  Website
# 17704  Application Support          Closed   Medium  Website
# 17705  Application Support          Closed   Medium  Website
#
#                     User AssignedAgent  ...        Agent EmailID  \
# 0      Microsoft Outlook    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 1      Microsoft Outlook    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 2      Microsoft Outlook    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 3      Microsoft Outlook    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 4      Microsoft Outlook    Ashok Wagh  ...  ashok.wagh@hp.co.in
# ...                  ...           ...  ...                  ...
# 17701     Ankita Meshram    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 17702       Amol Bhagwat    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 17703     Ankita Meshram    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 17704       Anket Tekade    Ashok Wagh  ...  ashok.wagh@hp.co.in
# 17705       Anket Tekade    Ashok Wagh  ...  ashok.wagh@hp.co.in
#
#         ClosureTime SLA_Response_Time SLA_Resolution_Time  LoginID        AA  \
# 0      312d 0h 41m                3.0                24.0      NaN  60+ days
# 1      312d 0h 41m                3.0                24.0      NaN  60+ days
# 2      312d 0h 41m                3.0                24.0      NaN  60+ days
# 3      312d 0h 41m                3.0                24.0      NaN  60+ days
# 4      312d 0h 41m                3.0                24.0      NaN  60+ days
# ...             ...               ...                 ...      ...       ...
# 17701           NaN               3.0                24.0  coppc11  60+ days
# 17702           NaN               3.0                24.0  coppc05  60+ days
# 17703           NaN               3.0                24.0  coppc11  60+ days
# 17704           NaN               3.0                24.0  coppc10  60+ days
# 17705           NaN               3.0                24.0  coppc10  60+ days
#
#       TimeDifferenceMinutes resp_minutes resp_hrs    DD
# 0                     452.0         14.0      0.0   0.0
# 1                     452.0         14.0      0.0   0.0
# 2                     452.0         14.0      0.0   0.0
# 3                     452.0         14.0      0.0   0.0
# 4                     452.0         14.0      0.0   0.0
# ...                     ...          ...      ...   ...
# 17701               14448.0          8.0      0.0  10.0
# 17702              135548.0         12.0      0.0  94.0
# 17703               10121.0          0.0      0.0   7.0
# 17704               73735.0         15.0      0.0  51.0
# 17705               73750.0         29.0      0.0  51.0
#
# [17706 rows x 48 columns]

# %%
# Check data types and null values
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17706 entries, 0 to 17705
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ticketid                   17706 non-null  int64
#  1   Ticket                     17706 non-null  object
#  2   CreationDate               17706 non-null  object
#  3   LastUpdated                17706 non-null  object
#  4   Type                       17706 non-null  object
#  5   State                      17706 non-null  object
#  6   Priority                   17706 non-null  object
#  7   Source                     17706 non-null  object
#  8   User                       17706 non-null  object
#  9   AssignedAgent              17706 non-null  object
#  10  UserLastNote               17706 non-null  object
#  11  icon                       17706 non-null  object
#  12  Subject                    17706 non-null  object
#  13  BU                         9935 non-null   object
#  14  BusinessFunction           9933 non-null   object
#  15  CaseCategory               10196 non-null  object
#  16  Resolution                 17706 non-null  object
#  17  Fiscal Year                17706 non-null  object
#  18  Quarter                    17706 non-null  object
#  19  Month                      17706 non-null  object
#  20  Ageing Bucket              17706 non-null  object
#  21  Ageing                     17706 non-null  int64
#  22  Day                        17706 non-null  int64
#  23  Year Month order           17706 non-null  int64
#  24  yearMonth                  17706 non-null  int64
#  25  Agent                      17706 non-null  object
#  26  Entity                     17706 non-null  object
#  27  creationDateTest           17706 non-null  object
#  28  CustomBU                   17706 non-null  object
#  29  Ageing_LastUpdated         17706 non-null  int64
#  30  Aging Bucket Last_Updated  17706 non-null  object
#  31  Deadline                   8516 non-null   object
#  32  DeadlineToToday            17536 non-null  object
#  33  Days                       8516 non-null   float64
#  34  resp1                      16384 non-null  object
#  35  D                          8516 non-null   float64
#  36  DevOnly                    17706 non-null  object
#  37  User EmailID               17658 non-null  object
#  38  Agent EmailID              17706 non-null  object
#  39  ClosureTime                8435 non-null   object
#  40  SLA_Response_Time          17104 non-null  float64
#  41  SLA_Resolution_Time        17104 non-null  float64
#  42  LoginID                    8521 non-null   object
#  43  AA                         17706 non-null  object
#  44  TimeDifferenceMinutes      17536 non-null  float64
#  45  resp_minutes               16418 non-null  float64
#  46  resp_hrs                   16418 non-null  float64
#  47  DD                         17536 non-null  float64
# dtypes: float64(8), int64(6), object(34)
# memory usage: 6.5+ MB

# %%
# Check for missing values
df_raw.isnull().sum()
# Out:
# ticketid                        0
# Ticket                          0
# CreationDate                    0
# LastUpdated                     0
# Type                            0
# State                           0
# Priority                        0
# Source                          0
# User                            0
# AssignedAgent                   0
# UserLastNote                    0
# icon                            0
# Subject                         0
# BU                           7771
# BusinessFunction             7773
# CaseCategory                 7510
# Resolution                      0
# Fiscal Year                     0
# Quarter                         0
# Month                           0
# Ageing Bucket                   0
# Ageing                          0
# Day                             0
# Year Month order                0
# yearMonth                       0
# Agent                           0
# Entity                          0
# creationDateTest                0
# CustomBU                        0
# Ageing_LastUpdated              0
# Aging Bucket Last_Updated       0
# Deadline                     9190
# DeadlineToToday               170
# Days                         9190
# resp1                        1322
# D                            9190
# DevOnly                         0
# User EmailID                   48
# Agent EmailID                   0
# ClosureTime                  9271
# SLA_Response_Time             602
# SLA_Resolution_Time           602
# LoginID                      9185
# AA                              0
# TimeDifferenceMinutes         170
# resp_minutes                 1288
# resp_hrs                     1288
# DD                            170
# dtype: int64

# %%
df_raw.columns
# Out:
# Index(['ticketid', 'Ticket', 'CreationDate', 'LastUpdated', 'Type', 'State',
#        'Priority', 'Source', 'User', 'AssignedAgent', 'UserLastNote', 'icon',
#        'Subject', 'BU', 'BusinessFunction', 'CaseCategory', 'Resolution',
#        'Fiscal Year', 'Quarter', 'Month', 'Ageing Bucket', 'Ageing', 'Day',
#        'Year Month order', 'yearMonth', 'Agent', 'Entity', 'creationDateTest',
#        'CustomBU', 'Ageing_LastUpdated', 'Aging Bucket Last_Updated',
#        'Deadline', 'DeadlineToToday', 'Days', 'resp1', 'D', 'DevOnly',
#        'User EmailID', 'Agent EmailID', 'ClosureTime', 'SLA_Response_Time',
#        'SLA_Resolution_Time', 'LoginID', 'AA', 'TimeDifferenceMinutes',
#        'resp_minutes', 'resp_hrs', 'DD'],
#       dtype='object')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17706 entries, 0 to 17705
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ticketid                   17706 non-null  int64
#  1   Ticket                     17706 non-null  object
#  2   CreationDate               17706 non-null  object
#  3   LastUpdated                17706 non-null  object
#  4   Type                       17706 non-null  object
#  5   State                      17706 non-null  object
#  6   Priority                   17706 non-null  object
#  7   Source                     17706 non-null  object
#  8   User                       17706 non-null  object
#  9   AssignedAgent              17706 non-null  object
#  10  UserLastNote               17706 non-null  object
#  11  icon                       17706 non-null  object
#  12  Subject                    17706 non-null  object
#  13  BU                         9935 non-null   object
#  14  BusinessFunction           9933 non-null   object
#  15  CaseCategory               10196 non-null  object
#  16  Resolution                 17706 non-null  object
#  17  Fiscal Year                17706 non-null  object
#  18  Quarter                    17706 non-null  object
#  19  Month                      17706 non-null  object
#  20  Ageing Bucket              17706 non-null  object
#  21  Ageing                     17706 non-null  int64
#  22  Day                        17706 non-null  int64
#  23  Year Month order           17706 non-null  int64
#  24  yearMonth                  17706 non-null  int64
#  25  Agent                      17706 non-null  object
#  26  Entity                     17706 non-null  object
#  27  creationDateTest           17706 non-null  object
#  28  CustomBU                   17706 non-null  object
#  29  Ageing_LastUpdated         17706 non-null  int64
#  30  Aging Bucket Last_Updated  17706 non-null  object
#  31  Deadline                   8516 non-null   object
#  32  DeadlineToToday            17536 non-null  object
#  33  Days                       8516 non-null   float64
#  34  resp1                      16384 non-null  object
#  35  D                          8516 non-null   float64
#  36  DevOnly                    17706 non-null  object
#  37  User EmailID               17658 non-null  object
#  38  Agent EmailID              17706 non-null  object
#  39  ClosureTime                8435 non-null   object
#  40  SLA_Response_Time          17104 non-null  float64
#  41  SLA_Resolution_Time        17104 non-null  float64
#  42  LoginID                    8521 non-null   object
#  43  AA                         17706 non-null  object
#  44  TimeDifferenceMinutes      17536 non-null  float64
#  45  resp_minutes               16418 non-null  float64
#  46  resp_hrs                   16418 non-null  float64
#  47  DD                         17536 non-null  float64
# dtypes: float64(8), int64(6), object(34)
# memory usage: 6.5+ MB
